# %% [markdown]
# # Define Function
#
# : 사실 python의 통곡의 벽 중 하나다. <br>
# function 에 제대로 들어가기 전에. 미리 안내를 하고 간다
#
# - function은 function call을 하지 않으면 skip 하고 넘어간다.
# <br> 이게 무슨 말이냐면 컴퓨터는 결국 funciton이 define 되어있을지라도,
# <br> 그걸 바로 보고 이해해두질 않는다.
#
# <br> **그럼 언제 이해해???** 그건 밑에서 출력을 할 때 해당 function을 call해줄 때
# <br> 그때 bottom - up 해서 top - down을 거친다.
#
# <br>
#
# 아 그냥 내가 원하는대로 쉽게 설명하겠다.
# <br>
#
# def function은 **외장 SSD** 정도로 생각하면 된다.
# <br> 이게 무슨 말이냐면 이미 우리가 파이썬에서 기본적으로 사용하는 모든 function들은 **내장 SSD** 같은 존재다
# <br> 우리가 뭔가 설정이나 뭔가 하지 않아도, 인터넷 브라우저에서 무언가를 다운 받으면? **내장 SSD**로 향한다.
# <br> 근데 어느새 용량이 가득차거나 아님 뭔가 내가 **외장 SSD**에 담아야 하는게 생겼다.
# <br> 그럴때 생각을 해보면 외장 SSD에 저장되게 할 때 인터넷 브라우저 혹은 다른 프로그램을 사용하면 편하게 사용 할 수 있다.
# <br> 예를 들면 .py로 끝나는 모든 파일은 **외장 SSD**에 저장 ! 이런거를 해두면 Github에서 .py 파일을 다운 받으면 외장 SSD로 간다
#
# <br><br> 그게 **외장 SSD**의 기본 기능이었을까? 그리고 다른걸 다운 받을때 매번 그걸 검사할까?
# <br> 절대 아니다. 우리가 설정을 해둔거고, 컴퓨터도 평소엔 무시한다. 근데 세팅해둔 조건에만 반응해서 **외장 SSD**로 옮겨주는 것 뿐이다.
#
# <br> 그러면 function call이란 무엇일까?
# <br> 우리가 **외장 SSD**에 들어가서 .py 파일을 더블클릭한다고 하자. 근데 만약 내가 **외장 SSD** 에서 열리는 모든 파일은 비밀번호를 입력해야 열림 이라는 조건을 걸어놨다면
# <br> 그때 잠들어있던 조건문이나 다른 우리가 설정해둔 기능들이 call 되는 것
#
# <br><br>
#
# - python function(=> 내장 SSD) : print, len . . . etc
#
# - Define function(=> 외장 SSD) : 지구상에 없는 기능을 내가 창조한다. 어떤 것이든 다 만들 수 있다
#
# <br>
#
# 그러면 왜 이걸 하는게 좋을까?
# 이건 실제 나의 예시인데 일단 아래 코드들을 보기 바란다.
# 내가 진짜로 했던 짓이다. 확실히 느껴질거다.

# %%
import sympy as sp
sp.init_printing()

x = sp.symbols('x')

ex1 = x**2 - 1
ex2 = x**2 + x
ex3 = x+3

cal_expanded = sp.expand(ex1 * ex2 * ex3)
display(cal_expanded)
######################################################
print('-----------------------성질----------------------------')

print('###교환법칙###')

cal_A = ex1 * ex2
cal_A_ep = sp.expand(cal_A)

display(cal_A)
display(cal_A_ep)

cal_B = ex2 * ex1
cal_B_ep = sp.expand(cal_B)

display(cal_B)
display(cal_B_ep)

print('-----------------검증-----------------')

if cal_A_ep == cal_B_ep:
    print('교환법칙 성립')
else:
    print('교환법칙 성립X')

######################################################

print('###결합법칙###')

cal_C = (ex1 * ex2) * ex3
cal_C_ep = sp.expand(cal_C)

display(cal_C)
display(cal_C_ep)

cal_D = ex1* (ex2 * ex3)
cal_D_ep = sp.expand(cal_D)

display(cal_D)
display(cal_D_ep)


print('-----------------검증2-----------------')

if cal_C_ep == cal_D_ep:
    print('결합법칙 성립')
else:
    print('결합법칙 성립X')

######################################################

print('###분배법칙(1)###')

cal_E = ex1 * (ex2 + ex3)
cal_E_ep = sp.expand(cal_E)

display(cal_E)
display(cal_E_ep)

cal_F = (ex1 * ex2) + (ex1 * ex3)
cal_F_ep = sp.expand(cal_F)

display(cal_F)
display(cal_F_ep)

print('-----------------검증3-----------------')

if cal_E_ep == cal_F_ep:
    print('분배법칙 성립(1)')
else:
    print('분배법칙 성립X (1)')

######################################################

print('###분배법칙(2)###')

cal_G = (ex1 + ex2) * ex3
cal_G_ep = sp.expand(cal_G)

display(cal_G)
display(cal_G_ep)


cal_H = (ex1 * ex3) + (ex2 * ex3)
cal_H_ep = sp.expand(cal_H)

display(cal_H)
display(cal_H_ep)

print('-----------------검증3-----------------')

if cal_G_ep == cal_H_ep:
    print('분배법칙 성립(2)')
else:
    print('분배법칙 성립X (2)')


# cf
# 하나하나 다 치다가 진짜 미칠 뻔 했다. 수학자 분들에게 존경을 표한다
#그런데, 여기서 하나 보여주고픈게 있다. 우리는 def와 친해져야 할 이유가 있다. 다음의 코드를 보자

def verify_all_polynomial_laws(A, B, C):

    sp.init_printing()

    # 1. 교환법칙
    is_commutable = sp.expand(A * B) == sp.expand(B * A)

    # 2. 결합법칙
    is_associative = sp.expand((A * B) * C) == sp.expand(A * (B * C))

    # 3. 분배법칙
    dist_left = sp.expand(A * (B + C)) == sp.expand(A * B + A * C)
    dist_right = sp.expand((A + B) * C) == sp.expand(A * C + B * C)

    # --- 결과 출력 섹션 ---
    print("\n" + "="*30)
    print('-----------------검증-----------------')
    print(f"1. 교환법칙: {'✅ 통과' if is_commutable else '❌ 실패'}")
    print(f"2. 결합법칙: {'✅ 통과' if is_associative else '❌ 실패'}")
    print(f"3. 분배법칙(좌): {'✅ 통과' if dist_left else '❌ 실패'}")
    print(f"4. 분배법칙(우): {'✅ 통과' if dist_right else '❌ 실패'}")
    print("="*30)


    if all([is_commutable, is_associative, dist_left, dist_right]):
        print('최종 결과 A*B*C')
        display(sp.expand(A * B * C))
    else:
        print("\n오류 발생")


verify_all_polynomial_laws(ex1, ex2, ex3)
#hahahahahahahahahahahahahahahahahahaaaaaaaaaaaaa 내 10분은 무너졌어.
# Out:
#  5      4      3      2
# x  + 4⋅x  + 2⋅x  - 4⋅x  - 3⋅x
# -----------------------성질----------------------------
# ###교환법칙###
# ⎛ 2    ⎞ ⎛ 2    ⎞
# ⎝x  - 1⎠⋅⎝x  + x⎠
#  4    3    2
# x  + x  - x  - x
# ⎛ 2    ⎞ ⎛ 2    ⎞
# ⎝x  - 1⎠⋅⎝x  + x⎠
#  4    3    2
# x  + x  - x  - x
# -----------------검증-----------------
# 교환법칙 성립
# ###결합법칙###
#         ⎛ 2    ⎞ ⎛ 2    ⎞
# (x + 3)⋅⎝x  - 1⎠⋅⎝x  + x⎠
#  5      4      3      2
# x  + 4⋅x  + 2⋅x  - 4⋅x  - 3⋅x
#         ⎛ 2    ⎞ ⎛ 2    ⎞
# (x + 3)⋅⎝x  - 1⎠⋅⎝x  + x⎠
#  5      4      3      2
# x  + 4⋅x  + 2⋅x  - 4⋅x  - 3⋅x
# -----------------검증2-----------------
# 결합법칙 성립
# ###분배법칙(1)###
# ⎛ 2    ⎞ ⎛ 2          ⎞
# ⎝x  - 1⎠⋅⎝x  + 2⋅x + 3⎠
#  4      3      2
# x  + 2⋅x  + 2⋅x  - 2⋅x - 3
#         ⎛ 2    ⎞   ⎛ 2    ⎞ ⎛ 2    ⎞
# (x + 3)⋅⎝x  - 1⎠ + ⎝x  - 1⎠⋅⎝x  + x⎠
#  4      3      2
# x  + 2⋅x  + 2⋅x  - 2⋅x - 3
# -----------------검증3-----------------
# 분배법칙 성립(1)
# ###분배법칙(2)###
#         ⎛   2        ⎞
# (x + 3)⋅⎝2⋅x  + x - 1⎠
#    3      2
# ...

# %%
#기본적으로 function을 define 하는 방법은 다음과 같다.
#def function_name(parameter):
    # <function> : 여기에 if, for , while, input ... etc) 우리가 배운 모든걸 다 넣을 수 있다.

    # return (prrameter_operation) #return은 여기서 빛을 본다. 괜히 내가 그렇게 구구절절하게 알려준게 아니다.

#먼저 function 을 우리가 가장 많이 본건 수학에서의 함수다.
# y = f(x) 라는 이 포맷을 본 적 없다? .... 괜....괜찮다 어쨋든 ! 여기서 치역은 y 이고, 정의역은 x 그리고 함수를 f 라고 한다
#근데 내가 말하고 싶은건 그게 아니다. 내가 말하고 싶은건 y = x+1 을 python으로 변환을 어떻게 할 수 있을까? 를 묻고 싶다
#음.. 일단 function name을 생각해보자. 아무래도 f 라고 하는게 가장 좋지 않을까? 그러면 parameter엔 x를 넣는게 이유는 모르겠으나 그림상 이뻐보인다 그냥..f(x) 이렇게 되면.. 이쁘잖아 ㅎㅎ..;;
#틀릴수도 있다. 괜찮다 진짜 괜찮다 우리가 원한게 아니라면 수정을 해서 우리가 원하는거로 바꿔내면 된다. 그러면 음.. x + 1 을 어떻게 표현할까? 
#아 수학에서 생각해보니. y = x + 1 이고 y = f(x)가 이게 무슨 말이냐면 잠시 수학을 좀 얘기해보자면

#원래 함수란 (x,f(x))를 의미한다. 예를 들면 x = 1 이면 (1,f(1)) 이라는건데 우리는 좌표평면에서 함수를 '시각화' 하고 싶다
#그걸 우리는 그래프라고 한다. 그래서 원래 좌표평면에 있는 곡선은 그래프고, 함수는 (x,f(x))다.
#다만 좌표평면에서 그걸 표현하는 과정에서 편의를 위해 y = f(x) 라고 가정하고, (x,y) 라고 쓰는 것이다.

#다시 돌아와서. y = x+1이라고 이제 쓸 수 있겠다. 그러면 왠지 <function> 부분에 y = x + 1이라고 해야할 것 같다
#음.. 그리고 return은 일단 y를 놔보고 만약 x = 3을 했는데 4가 나오지 않으면 그때 다시 수정을 해보자

def f(x):
    y = x+1
    return y 

print(f'f(3) = {f(3)}') #>> 4 , 제대로 구현한 것 같다. f(x) = x+1 일 때, x = 3 => f(3) = 3+1 = 4 
#def를 너무 어렵게 생각하지 말자. 우리가 해온걸 다시 보자. 우리 정말 많은걸 해왔다. 그 여정이 모두 function이랑 class에서 더 멋지게 놀기 위함이라고 해도 과언이 아니다
#생각해보자 지금 우리는 정말 그냥 y = x+1 이라는 것을 컴퓨터에게 알려준거다.근데 우리가 배운 내용을 다 썻나? 아니다 아직 제대로 놀지 않았다
#너무 아깝잖아 그 어려운 slicing이며 indexing이며 dict라던가 set이라던가 list comprehension도 같이 했는데 고작 이거에 무서움을 느낄거야?
# 일단 더 해보자. 결국 나노미터 단위로 쪼개면 전부 너무너무 쉽고 당연한거야 그리고 디 이 에프 에프 괄호 열고... 이러지 말고
# 나는 뇌에서 이렇게 돌려 "정의할거야 -> (뭐를?) -> 함수를 ! -> (이름이 뭔데?) -> f야 ! -> (parameter는 머야?) -> x야! -> (그걸로 뭐할건데?) ->
# -> x+1을 정의할거야 근데 매번 함수가 바뀔때마다 return도 바꿔야하면 귀찮으니까 y = x+1이라고 할게 -> (return 뭐 할거야?) -> y를 해야할 것 같아 x = 3이 되면 그 결과값을 y가 assign 받아줘야 하거든"
#진짜 그냥 딱 이게 속도만 다를 뿐 내 뇌에서 돌아가는 생각이야 충분히 가능해 그냥 대화를 해봐봐 그럼 정말 쉬울거야. 이건 자부할 수 있어
#나라고 처음부터 ReLu function. 이런걸로 시작했겠어? 충분히 가능해 정말 가능해. 해보자. 같이 해보자 당연히 쉬운 길은 아니야 나도 어려웠어

#근데 너는 달라 나는 return 에 대한 것도 정말 어려운 용어로 어렵게 배웠어. 뇌가 터질 뻔 했지 이해하려고 하는데 뭔 말인지를 모르겠으니까 우리 인간은 return을 굳이 안해도 살아가는데 지장이 없으니까
#끝까지 초심 잃지 않고 따라와줘. 속도는 느려도 돼 대신 하나하나 확실히 하고 와주라. 그래서 내가 예제를 많이 안 넣는거야
#내가 가장 싫어하는거거든 예제는 더럽게 많은데 설명은 부실하고 해설지나 설명을 들으면 전문용어 팍팍 써가면서 나 똑똑해요~ 하는거
#예제 20개 생각 안하고 풀면서 손가락만 지칠빠엔 차라리 정말 방금 우리가 한 y = x+1 에 대한 function 코드 세줄이라도 그 누구보다 쉽게 설명하려고 뜯어봐
# 그게 예제 10개의 효과는 분명히 날거야
 

#이제 진짜 예제를 보자. 
#미리 말하지만, 절대 그냥 눈으로만 보지 말고 자신만의 언어로 해석해서 이해를 하자. 
#진짜 진심이다.. 눈으로 이해했음에 속지 말자. 눈으로 보고 생각을 거쳐 결국 스스로 설명 할 줄 아는 상태를 이해라고 하는거고 그걸 어린 아이가 이해 되게 설명 할 줄 알면 그건 지식이 된거다.

def plus(a,b):  #function name : add 라고 하겠다. parameter는 a,b가 필요하다.
    return a+b  #add라는 function을 call을 할 땐 add(1,2) 처럼 써야하는데, 그러면 우리가 제공해줄 기능은 a+b니까 3이 출력될거다

print(f'plus function call(a = 1, b = 2) = {plus(1,2)}')
#나는 설명을 위해 이렇게 쓴거지 평소엔 다음과 같은 방식으로 작성한다.

function_sum = plus(1,2) #여기서 plus를 부른 것이 function call이다. 
print(function_sum)

#구분하자. 내장 ssd와 외장 ssd는 다르다
#당장 그 어떤 파이썬이든 plus 라는 name으로 function을 define 하지 않아놓고
#그냥 plus 라고 쓰면 str로 인식한다 

#더 나아가보자.

def plus_2(a,b): #function name : plus_2, parameters : a, b
    sum_ab = a+b #variable name : sum_ab이고 assgin 된건 a+b 이다.
    return sum_ab #plus_2 라는 function 을 call 하면 우리가 제공 할 기능은 sum_ab에게 assign 된 a+b 라는 기능이다.

c = plus_2(10,15) #parameter a = 10 , b= 15
print(f'plus_2 fucntion call(a = 10, b = 15) = {c}')

#docs 라는걸 알려주고 싶다.
#나는 지금 계속 #으로 옆에 무언가를 주렁주렁 달고 있는데 이런걸 우리는 '주석' 이라고 부른다
#docs는 설명서다. 근데 class랑 def에선 이 docs가 정말 ... 너무너무 중요하다. 
#docs에는 많은 내용을 담을 필요 없다. 무엇을 입력하면 무슨 기능이 되야합니다. 이런 정도면 충분하다. 아까 plus function에 docs를 추가해보겠다.

def plus(a,b,c):
    """a,b,c를 parameter로 입력 받으면 a+b+c 가 return"""
    result = a + b + c
    return result

#이걸 그럼 왜 작성할까?
# 1. 협업에서의 인수인계 과정 축소
# 2. black box 상태에서의 안정성 검증

#black box란 내부 기능은 모르겠지만, 입력과 출력만 보겠다는거다.
#안에서 무슨 일이 벌어지는지는 모른다. 다만 입력과 출력만 보고 docs랑 비교하는 작업이다.
#마치 이런거다. 술집 안에서 싸움이 났고, 가보니 시체가 한 구 발견이 되었다.
#그러면 black box적으로 생각을 해보면 안에서 어떠한 둘 이상이 싸웠다. 한 명이 사망했다.
#그 내부에서 뭐 총을 쐇니, 칼을 사용했니 그건 나중에 봐야 할 문제고 결국 지금 이 경찰관이 생각해야하는건 '살인사건이다.' 이거만 생각하면 된다.

#더 나아가보자.
#이번엔 parameter가 필요 없는 경우를 보여주겠다.

def function():
    """parameter는 없고, function call 되면 call 이라는 str이 return"""
    return 'call'

print(f'function {function()}') # 좀 웃기지만 작성해봤다.

print('-------------------------------------')
#그러면 이제 우리에겐 상식 퀴즈로 가보자.

def sq(a,b):
    print(f'result = {a*b}')
    

#여기서 내가 만약
a = sq(2,5)
print(f'a = {a}') #이걸 하면 무엇이 출력될까 ? 
#hint: variable_name = list_name.append(element)
#print(variable_name)

#당연히 None이 출력된다.
#더 작성 할 내용이 없다. remind 차원에서 set을 다룰때 설명했던 비유를 다시 적고 간다.
#그 전에 정상적으로 function call을 해보자.

sq(5,5)

#왜 None인지 이제 이해를 했겠지만 너무너무 중요한 개념이라서 한번 더 짚고 넘어간다

#set_name.add(element)의 우선순위는 다음과 같다 
# 1. set_name이라는 set에 element를 배송해준다
# 2. 다시 물류센터로 온다

#근데 여기서 고객이 직접 와서는 "제 택배 주세요."  그러는거다
#이미 근데 우리는 배송을 완료했다. 이미 해당 고객 집 문 앞에 두고 왔다.
#그 고객이 바로 좌변 즉 variable_name이 되는거다. 

#variable_name라는 고객 입장에서도 사실 타당하다.
#고객은 결국 배송물품을 받아야 한다.
#그래서 물류센터로 왔는데 이미 배송 기사님께서 배송을 집 문 앞에 배송을 하고 오셨다
#그럼 하나를 더 받을 수 있을까? 이미 집 앞에 있는데? 그건 불가능하다.
#그래서 None을 assign 받는 것이다. 택배사 입장에선 당장 줄 것이 없으니까

#여기서 return 개념을 엮는 방법은 다음과 같다 어려워도 이해해주길 바란다  내 뇌를 그대로 복붙 했다.
#우선 우리의 sq 라는 function은 sq(2,5) 라는 부분에서 parameter를 a= 2 b = 5로 인식했고 
#이미 a = sq(a,b)를 하는 순간 function call이 된거라서 sq function에서 출력해줘야하는 기능은 
#'result = a*b를 진행해서 배송을 해주었다.

#그런데 거기서 갑자기 variable인 a가 "나도 뭔가 줘!!" 라고 하는데 sq function은 철저히 
#주문한 고객에게만 결과를 반환한다. 그래서 None을 주고 떠난다.

print('-------------------------------------')

#parameter를 지정해서 function call을 진행해보자.

def minus(x,y):
    return x-y

c = minus(x= 24,y =20)
print(f'minus function call(x = 24, y = 20) = {c}')

#생각을 해보자. 왜 위에랑 다르게 None이 아닐까 ? 
#list로 치면 sorted와 sort의 차이이다.

#return이 존재하는 function에선 x-y 라는 기능을 한 뒤, 다시 제 자리로 가져다준다
#그러면 c 라는 variable 에겐 4 라는 값이 assign 되는 것이고, minus(x=24, y=20) 의 자리엔 x - y 의 결과값이 replace 되는거다.

#parameter를 열린 해석으로 두고 싶은 상황에 대해 고민 해보자.
#만약에 우리가 뭔가 parameter를 (a,b,c) 이런식으로 딱 개수를 정해서 쓰면 안될 것 같은 상황에 직면했어
#그러면 무엇을 사용해야 이 난관을 이겨낼 수 있을까 ? 매번 이걸 하나씩 늘릴까?
#근데 그러면 뭔가 좀.... 그렇지 왜냐면 그게 10개만 되더라도 너무 길어지거든

#그래서 내가 도입한게 *args 라는 거야 (arguments의 약자인데, 관례상 *args 라고 하는거야 )
#아래의 예제 코드를 보자.

print('-----------------------------')
def so_many(*args): #function name : so_many / parameter : variable parameter 
    result = 0 #Init variable, result 라는 variable을 사용 할 준비 정도만 해두고 끝낸다.
    for i in args: #loop variable i, range : variable, 즉 args는 function call에 따라 바뀐다. 
        result = result + i #result 라는 variable은 assign이 0으로 되어있다. 그런데 i는 loop variable이니 range 만큼 result에게 준다.
        #더 설명을 해보자면 이런거다. i가 1을 가져오면, result(좌변 및 우변)에겐 1이 assign 되고(왜냐면 i = 1일땐, result = 0이었으니까)까 
        # 다시 i = 2를 향해 loop를 돌면 이땐 result(우변)에 1이 assign 상태였다가
        #i= 2가 들어오니 1+2 이런 구도가 되고 그걸 = 3 한 뒤 좌변이 assign된다, i는 다시 loop를 돌기 위해 떠나야 한다 그리고 다시 똑같은 loop 를 반복한다.
        #그러다 최종적으로 i = 5일땐, 이미 result 는 10이라는 값이 assign 된 상태이니, result(~=현재 assign) = 10 + i가 되는데 이때 i = 5니까
        #result = 15로 changing binding 한다

        #그러면 return result에 있는 result에는 changing binding된 15라는 값으로 return을 돌리면 function call 지점에 15라는 값을 배송한다.
    return result  #어렵게 생각 안해도 된다. 아까 우리 y = f(x)를 생각해보면 그냥 y = x+1 에서 x+1을 항상 바꾸긴 귀찮으니 y를 return으로 준거랑 똑같다.

cal = so_many(1,2,3,4,5) #call function, 여기서 paramerter가 정해진다. type : tuple
print(f'cal variable = {cal}') #so_many(1,2,3,4,5)에선 분명 result가 return되면 현재 cal 이라는 variable이 assign 한 so_many(1,2,3,4,5) 가 replace 된다.

#다음 예제를 봐보자.

def add_mul(choice, *args): #이번엔 Immutable parameter(=> choice)랑 mutable parameter(=> *args)가 동시에 쓰였다, function name : add_mul
    if choice == "add": #만약 choice로 add를 입력 받으면? - 사건 A
        result = 0 #result 에 0을 assign 할거야 => Init variable
        for i in args: #i 라는 loop variable은 args 입력 받은 만큼 움직일거야.
            result = result + i 
            #i = 1이면 우선 result = 0인 상태서 result = 0 + 1이 먼저 되고, 그리고나서 result (좌변)에 1이라는 값이 assign 되는거야
            #i = 2가 올 차례일땐 우변 result에 1 이라는 값으로 이미 assign 되어있고 좌변 result도 1 이라고 binding을 해둔 상태야
            #그러면 result = 1이라고 가정하자. 그때 i = 2면 이런 구도겠지. result = result + i 여기에 이제 수를 assign 해.
            #그러면 3이 되네? result엔 3으로 chaning binding 되는거야. 이렇게 입력만큼 받은 진행하는거야 
    elif choice == "mul": #만약 사건A는 발생하지 않았는데(=> add를 입력하지 않았다면) mul을 입력했다면? - 사건B
        result = 1 #result에 1 이라는 값으로 assign 해둘거야 (여기를 1로 해두는 이유가 있어)
        for i in args: #그리고 i 라는 loop variable은 args 입력 받은 만큼 움직일거야
            result = result * i #여기가 달라. 그리고 여기서 result를 1로 해둔 이유가 있어
            #mul 즉 곱셈에선 * 0 을 하는 순간 0으로 돼, 근데 그러면 result는 계속 i가 다른 수를 가져와도 이미 자기가 0으로 반복해서 binding 받았으니까
            #그걸로 loop variable이 가져온 값을 상쇄시켜버려 
            #그래서 result = 1이라고 두는거야
    return result  #사건 A인지 사건B인지 뭐가 일어났는지는 컴퓨터는 몰라. 단지 top - down 하고 최종적으로 assign된 result의 값만 보는거야 그리고 그걸 배송해주는거고

mul_1 = add_mul('add', 1,2,3,4,5)
mul_2 = add_mul('mul', 6,7,8)

print(f'mul = {mul_1}')
print(f'mul = {mul_2}')

#그러면 이제 keyword arguments 대해 다뤄보자.
#우선 사용은 다음과 같이 하는 편이다. 
# keyword = 값 

#음... 개인적으로는  진짜 지극히 개인적으로는 그냥 .. dict처럼 보인다
#(사실 dict가 맞다.) 
#더 설명은 생략하고 코드에서 더 많은걸 보고 생각해보자.

def dict_func(**kwargs):
    print(f'입력한 Keyword : {kwargs}')

dict_func(Key = 'apple', Value = '사과') 

#여기서 만약 만약 내가 x = .. 이라고 하고 print(x)를 하면 어떻게 될까?
#한번 해보자. 해보고 안되면 그냥 에휴에휴 인거고 되면 오호.. 왜 그런거지? 하고 뜯어보면 된다

x = dict_func(Key = 'apple', Value = '사과')
print(x) #이제.. 안봐도 비디오 아니야? 믿을께..??? 
#그럼 반대로 이렇게 하면?
print('---------------------')
print(dict_func(Key = 'apple', Value = '사과'))

#그러하다. 일단 function call은 제대로 해주더라도, print에게 줄 것은 없어진 상태라고 보면 편할 것 같다.

#그럼 이걸로 좀 더 가지고 놀아보자. 어차피 우리 같이 공부한 것도 산더미인데 틀려도 보고 이상한 것도 출력해보고 그러면서
#차차 우리가 배운걸 더 단단하게 이해하는거지 그게 얼마나 감사한 일인데 

#해보자.

in_key = input('Key 값 입력 = ')
in_value = input('value 값 입력 = ')

dict_func(Key = in_key, Value = in_value)

print('---------------------------')

#이제 paramet를 먼저 assign 해두고 시작해보면 어떨까?

def info(name, age, man=True): 
    print(f"이름 : {name}.") 
    print(f"나이: {age}살.") 
    if man: 
        print("Man")
    else: 
        print("Girl")

#일단 시작을 해볼께. 
#밑에 출력부를 먼저 보고, 그리고 한번 같이 뜯어보자.

info('전현준',21) 
#>>이름 : 전현준.
#>>나이: 21살.
#>>Man

#보면 우리는 컴퓨터에게 성별을 말해준 적이 없는데 자동으로 Man이라고 했어
#해킹일까? 일단 코드를 뜯어보고 해킹인지 아닌지 의심 해보자

def info(name, age, man=True): 
# 여기서 우선 name, age를 parameter로 받는다는건 이제 이해가 될거야. 그리고 man = True만 우리가 처음보는건데
#쫄지마 이것도 진짜 쉬워 이건 그냥 난 이렇게 보는 편이야 "뭐야 bool 값을 True로 미리 Assign 해놨네? 나중에 뭐 조건문 쓰나 ?" 그냥 딱 이거로만 생각하고 넘어가 
    print(f"이름 : {name}.")  #이건 이제 알거라 믿어..
    print(f"나이: {age}살.")  #이것도 알거라고 난 정말 믿어... 진심이야. 우리 함께 한 여정에 다 포함되어 있어
    if man:  #여기서부터 중요해. if 조건문으로 들어왔는데 너무너무 신기하지 왜? 그전엔 뭐 비교를 한다던가 같냐 틀리냐 뭐하냐 저쩌냐 이런걸 따졌는데 여기선 그게 없어
        #그냥 man? 이라는 사실만 보고 있어 . 근데 봐봐 조건문에서 결국 중요한게 뭐야? True / False 잖아
        #그러면 어떻게 되겠어? 우린 이미 True로 해두었잖아 그러면 if에서 "아 너 True야? 뭔진 몰라도 우리 주인이 True라고 하네? 너 일단 검문 통과해"
        print("Man") #그래서 이게 출력이 되는거지
    else: 
        print("Girl")

#근데 만약 아 나는 Girl 도 출력해보고 싶어!! 라고 하면
#여기선 쉽게 이거를 생각해. changing binding

#내가 왜 이걸 강조하냐면
#밑에 봐봐

info('박초현',21, False) #친구 이름이야. 
#여기서 중요해. 박초현은 False야. 맞아 틀려먹었어 아니 잠만 미안 다시.
#여기서 False라고 쓰면서 박초현이라는 정보에 대해서는 지금부터 False로 binding 한거야
#그러면 False man 이 되는거겠지?

#그리고 다시 

def info(name, age, man=True): 
#여기서 이제 다시 가공을 해야해 name 받았어 박초현이래, age 받았어 21이래 man인가 봤더니 False Man이래
#그러면 여기서 man = False로 changing binding 된 느낌이라고 이해해볼 수 있을까?
#그럼 이제 여기서 밑으로 검문소로 보내기 전에 다 세팅을 해두는거야
#name : 박초현 , age : 21 , man = False 
#이제 검문을 받으러 가보자.
    print(f"이름 : {name}.")  #이건 이제 알거라 믿어.. 
    print(f"나이: {age}살.")  #이것도 알거라고 난 정말 믿어... 진심이야. 
    if man: #첫번째 검문이야 man이냐고 물어보니 우리가 내미는건 False야 근데 조건문에선 True/False 가 좌우한다했지?
        print("Man")  #그럼 여기선 "출력 불가십니다. 저는 True일때 님이랑 궁합이 맞아요."
    else: #if에선 검문 후 실패를 맞이했어. 그럼 이제 그것의 여사건인 else엔 모두 가능하겠지 ?
        print("Girl") #그럼 남은게 이거 밖에 없네. 이거라도 출력해야지

#어때 진짜 쉽지.
#근데 만약에 False라고 해놓고 내가 man 이라고 출력하고 싶다면 어떤 방법이 있을까?
#이렇게 하면 돼

print('---------------')
def info(name, age, man = True):
    print(f'이름 : {name}')
    print(f'나이 : {age}')

    if not man:
        print("Man")
    else:
        print("Girl")

info('박초현',21, False)
#LOOK ! 보여???? 출력창 보여?????? Man이 나오지
#이것도 정말 쉬워 if not이면 결국 '만약 그렇지 않으면~' 이잖아
#근데 if not man 이면 남자가 아니라면? ~= man = False 라면? 그럼 이 조건문 입장에선 'True' 가 되서 검문 통과가 되거든

#다음으로 넘어가자.

print('-------------------------')

#global and local

#global 과 local..은 진짜 별거 없어 쉬워
#그냥 뭐 새로 배우는게 아니야 그냥 약속이야 약속
#예를 들어서 우리가 아까 가장 처음 같이 만든 y = f(x)를 내가 가져와볼께

def f(x):
    y = x+1
    return y

#이거였잖아? 근데 지금 f라는 function 안에 보면 y 라는 variable이 있지 ? x+1 을 assign 했잖아
#근데 만약 내가 이걸 f라는 function 밖에서도 하고 싶다면 ?
#한번 해보자. 틀려도 돼 진심이야.

#그냥 난장판을 만들어볼께.

y = 2

def f(x):
    y = x+1
    return y 

y = 4
y = 20
print(f'current local y = {y}') # >> 20

y = f(5) # >> 6
print(f'f(5) = {f(5)}') 

#보면 알겠지만, 분명 variable name은 동일한데
#function f 내부에 y 라는 variable은 changing binding의 영향을 일절 받지 않았어

#왜 그런걸까 ?
#이게 바로 global variable과 local variable의 차이야

#function 내부 있는 모든 function을 local variable 이라고 불러
#여기서 local은 각 function을 의미하겠지?

#그러면 global은 ?
#그냥 함수 밖이야 난 여기서 종종 생각하는건 local variable이 사건 A 즉 P(A) 라면
#global variable은 그의 여사건이라 생각하는 편이야 

#그럼 너도 봤지만
#changing binding에 영향을 받는건 global이지

#근데 이런 경우엔 어떻게 될까?
#function 내부에서 local variable이 local variable을 changing binding 하는 경우
#해보자. 가장 쉬운 예시로 하면 될거야 y = x+1 이랑 y = x+2를 둬보면 되는거 아니겠어?

print('-------------')
def f(x):
    y = x+1
    y = x+2
    return y

print(f'f(3) = {f(3)}')
#y = x + 2로 changing binding 된거네

#이제 좀 더 재밌는걸 해보자. 
#Recursive function 이라는 내용인데 진짜 너무너무 재밌어 이거
#일단 한글로 말하면 재귀 함수. 라는 말인데 너무 좋은 예시가 있어

#수학에서 가장 쉬운 예로는 factorial 이야
#factorial 이란 n! = n * (n-1) * (n-2) * ... * 1 이런건데
#그냥 쉬운 예시로 3! = 3 x 2 x 1 = 6 이런거야

#이걸 파이썬으로 구현해보자 어떻게 해야할까?
#일단 우리가 생각해야하는건 factorial은 끝이 정해져있어 
#결국 *1을 하는 순간은 필연적으로 오게 되어있지

#그럼 그거부터 설계를 하자.

def fac(n):
    if n <= 1:
        return 1
    #그리고 뭘 해야할까?
    #이제 남은건 n*(n-1)*(n-2).... 이런거잖아
    #조건이 뭐가 필요해? 아니야 그냥 나타나주기만 하면 돼
    #그럼 return이 필요하겠다.

    return n * fac(n-1)
    #이 부분이 바로 recursive야
    #우리가 이미 define한 function을 local에서 불러왔어
    #그러면 n = 3이 들어왔다 생각해봐. 
    # n = 3을 넣어. 그러면 if 조건문은 자연스레 넘어가지 1보다 크고 같지 않으니까
    #그러면 return n * fac(n-1)로 온건데
    #n = 3이지 그러면 3 * fac(3-1) 이니까 fac(2)를 한번 더 하는거야

    #그럼 다시 fac(2)일때 function을 돌려봐
    #일단 1보다 크고 1이 아니니까 조건문은 넘어가 
    #그러면 return n * fac(n-1)을 만나지
    #여기서 n = 2라는거야 그러면 2 * fac(2-1)이 되는거야
    #일단 현재까지 fac(3)에서 n * fac(n-1) 부분은 이렇게 되는거지

    #3 * 2 * fac(1) 

    #그럼 여기서 또 한번 fac(1)을 function call을 해주네
    # 그럼 다시 fac(1)을 돌려봐
    # 그러면 어!!!!!!! 이번엔 if 조건문에서 "하.. 이놈 또 왔네.. 어 잠만 잠만 스탑 너 이번엔 좀 수상해 우리 명단 좀 다시 볼께"
    # 이러고 있는거야 근데 보니까 명단에서 잡으라고 한 애들에 속하지 그럼 if 조건문이 "우리 대화 좀 하자 일단 나한테 들어와봐" 하니까
    # n = 1인 상태인데 return n 이 바로 있으니까 뭐 탈출도 못하고 바로 1 을 뱉어내는거야
    # 
    # 그러면 이제 끝났네. 
    # fac(3) 한번 돌렸다가 온갖 짓 다했어 이제 출력해보자.

fac(3) # >> 6 (<=> 3*2*1)

#어때 너무너무 쉽지 이게 Recursive야 다른거 많이 멋진거 보여줄 수 있는데 일단 이 코드를 완전히 이해하자.
#왜냐면 우린 이제 마지막으로 더 멋진거 하고 딱 끝낼거야 

#list에서도 list comprehension이라는 아주 멋진걸 공부했어
#근데 function엔 그런게 없을까? 오히려 더 멋져야 정상 아닌가??
#맞아 있어 lambda 라는거야

#이건 function을 한줄로 나타내게 해줘 
#이렇게 쓰면 돼 
#function name = lambda paramert1_name, parameter2_name: expr
#이렇게 보면 그 어떤 것보다 어려워보여 근데 아니야 진짜 쉬워 한번 같이 보자.

plus = lambda a, b: a+b 
ps_1 = plus(3,4)

print(f'ps_1 = {ps_1}') 

#여기서 신기한건 분명 plus(3,4) 이런 식으로 하면 return이 없으니까
#ps_1 에겐 None이 assign 되야.. 하는거 아닌가? 라고 생각 할 수 있어.
#이게 lambda의 특징인데 lambda 는 return이 없어도, 결과값을 return 해줘
#그래서 ps_1 에게 3+4의 결과값인 7이 assign 된거야

#그럼 이제 생각을 해보자.
#과연 저걸 def로 쓴다면 어떻게 쓸 수 있을까?
#음.. 일단 function name은 plus라고 지을래

# def plus(): 
#parameter는 뭘 넣어야 할까? 일단 바로 a,b가 보이니까 그냥 이쁘게
#a랑 b 넣을래
#def plus(a,b):
#그리고 음... 뭘 해야할까?
#그냥 바로 return을 걸면 되나..? 
#해보자.
#return a+b

#이제 이걸 코드로 옮겨볼께

def plus(a, b):
    return a+b 

ps_2 = plus(3,4)
print(f'ps_2 = {ps_2}')
#제대로 구현했다 ! 어때? 너무너무 쉽지

#놀라운 사실은... 이게 function의 주요 내용은 본거야
#진짜 우리 많이 달려왔어.

#이제 진짜 남은건 class야.
#미리 안내할께. 어려워. 정말 어려운게 맞아. python의 통곡의 벽 중 하나야
#근데 미리 또 안내할께. 진짜 재밌어. 겁 먹을 정도는 아니야. 

#이런 생각을 하면 좋겠어. 결국 아무리 어려운 것도 그게 있는게 더 편하니까 만들어진거야
#그게 없으면 더 어려웠을 것을 더 쉽게 하게 해준건데
#우리가 공부를 안하면 우리만 고생인거지 편한게 있는데 그걸 우린 조금 어렵다는 이유로 안해! 하는거니까
#그러니까 한번 같이 해보자.

#대신. 
#function에서 정말 많은 내용을 다루었어
#한번 직접 코드도 쳐보고, 많은 실수를 하고 넘어왔으면 좋겠어
#유의미하든 무의미하든 괜찮아 그러면서 배우는거야
#error이랑 친해져봐 error log는 우리를 놀리는게 아니라 우리에게 부탁하는거야
#제발 실행하기 위해 여기를 고쳐주세요 !! 저는 바보라 고칠 능력이 안됩니다 ㅠㅠㅠ 이러고 있는거야

#이제 class로 가보자. ㅎ
# Out:
# f(3) = 4
# plus function call(a = 1, b = 2) = 3
# 3
# plus_2 fucntion call(a = 10, b = 15) = 25
# function call
# -------------------------------------
# result = 10
# a = None
# result = 25
# -------------------------------------
# minus function call(x = 24, y = 20) = 4
# -----------------------------
# cal variable = 15
# mul = 15
# mul = 336
# 입력한 Keyword : {'Key': 'apple', 'Value': '사과'}
# 입력한 Keyword : {'Key': 'apple', 'Value': '사과'}
# None
# ---------------------
# 입력한 Keyword : {'Key': 'apple', 'Value': '사과'}
# None
# 입력한 Keyword : {'Key': 'ant', 'Value': '개미'}
# ---------------------------
# 이름 : 전현준.
# 나이: 21살.
# Man
# 이름 : 박초현.
# 나이: 21살.
# Girl
# ---------------
# 이름 : 박초현
# 나이 : 21
# Man
# -------------------------
# current local y = 20
# f(5) = 6
# -------------
# f(3) = 5
# ps_1 = 7
# ps_2 = 7
